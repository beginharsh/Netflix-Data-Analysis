# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.sample(5)
# Out:
#      show_id     type                       title               director  \
# 5394   s5395    Movie  Hans Teeuwen: Real Rancour  Doesjka van Hoogdalem
# 3529   s3530    Movie                      Evelyn  Orlando von Einsiedel
# 6171   s6172    Movie        Ant-Man and the Wasp            Peyton Reed
# 5715   s5716  TV Show                     La Niña                    NaN
# 6548   s6549    Movie                         Dad    Gary David Goldberg
#
#                                                    cast         country  \
# 5394                                       Hans Teeuwen     Netherlands
# 3529                                                NaN  United Kingdom
# 6171  Paul Rudd, Evangeline Lilly, Michael Douglas, ...   United States
# 5715  Ana María Estupiñán, Sebastian Eslava, Juan Se...        Colombia
# 6548  Jack Lemmon, Ted Danson, Olympia Dukakis, Kath...   United States
#
#               date_added  release_year rating  duration  \
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.size
# Out:
# 105684

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.drop(['show_id','description'],axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#          type                                            title  \
# 5492    Movie  Norm Macdonald: Hitler's Dog, Gossip & Trickery
# 6454    Movie                                     Chauthi Koot
# 232   TV Show                                 Wheel of Fortune
# 6667    Movie                           Eh Janam Tumhare Lekhe
# 5402    Movie                              The Invisible Guest
#
#              director                                               cast  \
# 5492       Liz Plonka                                     Norm MacDonald
# 6454  Gurvinder Singh  Suvinder Vikky, Rajbir Kaur, Gurpreet Kaur Bha...
# 232               NaN                             Pat Sajak, Vanna White
# 6667     Harjit Singh  Pavan Malhotra, Sudhanshu Aggarwal, Arjuna Bha...
# 5402      Paulo Oriol  Mario Casas, Ana Wagener, José Coronado, Bárba...
#
#             country        date_added  release_year rating   duration  \
# 5492  United States       May 9, 2017          2017  TV-MA     61 min
# ...

# %%
df.isna().sum() # Checking count of null values in each Column
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# dtype: int64

# %%
df["country"].value_counts().head(3) # Top 3 highest occuring countries
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Name: count, dtype: int64

# %%
mode_country = df["country"].mode()[0] # Highest Occuring State
mode_country
# Out:
# 'United States'

# %%
df["country"] = df["country"].fillna(mode_country) # replacing country column null value to mode value of that column.

# %%
df["country"].isna().sum() # cross checking to make sure that changes happened.
# Out:
# np.int64(0)

# %%
mode_date = df["date_added"].mode()[0]
mode_date
# Out:
# 'January 1, 2020'

# %%
df["date_added"] = df["date_added"].fillna(mode_date)

# %%
df["date_added"].isna().sum()
# Out:
# np.int64(0)

# %%
mode_rating = df["rating"].mode()[0]
mode_rating
# Out:
# 'TV-MA'

# %%
df["rating"] = df["rating"].fillna(mode_rating)

# %%
df["rating"].isna().sum()
# Out:
# np.int64(0)

# %%
mode_duration = df["duration"].mode()[0]
mode_duration
# Out:
# '1 Season'

# %%
df["duration"] = df["duration"].fillna(mode_duration)
df["duration"].isna().sum()
# Out:
# np.int64(0)

# %%
df["director"] = df["director"].fillna("Not Mentioned") # Replacing null values with Default Value -- Not Mentioned

# %%
df["director"].isna().sum()
# Out:
# np.int64(0)

# %%
df["cast"] = df["cast"].fillna("Not Mentioned") # Relacing Null Values with Default Value
df["cast"].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# type            0
# title           0
# director        0
# country         0
# release_year    0
# rating          0
# duration        0
# Year            0
# Month           0
# Day             0
# Genre           0
# Lead_actor      0
# dtype: int64

# %%
df["rating"].unique() # checking the unique/distinct values in rating column
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR',
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df = df[~df["rating"].str.contains("min")] # removing the wrong format rating rows
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df["date_added"].unique()
# Out:
# array(['September 25, 2021', 'September 24, 2021', 'September 23, 2021',
#        ..., 'December 6, 2018', 'March 9, 2016', 'January 11, 2020'],
#       shape=(1766,), dtype=object)

# %%
df["date_added"] = df["date_added"].str.replace(",","") # replacing/removing the comma with blank in date_added Column 
df["date_added"].unique()
# Out:
# array(['September 25 2021', 'September 24 2021', 'September 23 2021', ...,
#        'December 6 2018', 'March 9 2016', 'January 11 2020'],
#       shape=(1766,), dtype=object)

# %%
df["date_added"] = pd.to_datetime(df["date_added"],format="mixed") # function to convert strings to datetime objects
df["date_added"].unique()
# Out:
# <DatetimeArray>
# ['2021-09-25 00:00:00', '2021-09-24 00:00:00', '2021-09-23 00:00:00',
#  '2021-09-22 00:00:00', '2021-09-21 00:00:00', '2021-09-20 00:00:00',
#  '2021-09-19 00:00:00', '2021-09-17 00:00:00', '2021-09-16 00:00:00',
#  '2021-09-15 00:00:00',
#  ...
#  '2018-09-27 00:00:00', '2017-03-23 00:00:00', '2016-12-25 00:00:00',
#  '2016-11-30 00:00:00', '2017-10-23 00:00:00', '2017-11-04 00:00:00',
#  '2015-08-05 00:00:00', '2018-12-06 00:00:00', '2016-03-09 00:00:00',
#  '2020-01-11 00:00:00']
# Length: 1714, dtype: datetime64[ns]

# %%
pd.isnull(df).sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df["Year"] = df["date_added"].dt.year # extracting year from a datetime column

# %%
df["Month"] = df["date_added"].dt.month # extracting month from a datetime column

# %%
df["Day"] = df["date_added"].dt.day # extracting day from a datetime column

# %%
df.sample(5)
# Out:
#          type                                  title  \
# 8091    Movie                                  Still
# 781     Movie  Black Holes | The Edge of All We Know
# 7552    Movie                Mythily Veendum Varunnu
# 5404  TV Show                      The Truth Seekers
# 7378    Movie                               Magnetic
#
#                                                director  \
# 8091  Chatchai Katenut, Manussa Vorasingha, Tanwarin...
# 781                                       Peter Galison
# 7552                                      Sabu Varghese
# 5404                                      Not Mentioned
# 7378                                     Thierry Donard
#
#                                                    cast        country  \
# 8091  Mai Charoenpura, Akara Amarttayakul, Supakson ...       Thailand
# 781                                       Not Mentioned  United States
# 7552  Udhay, Kiran Raj, I.M. Vijayan, Sandhanam, Shi...          India
# ...

# %%
df["Genre"] = df["listed_in"].str.split(",").str[0] # splitting the column using comma(,) and making a new column

# %%
df["Genre"].value_counts().head(5)
# Out:
# Genre
# Dramas                      1592
# Comedies                    1204
# Action & Adventure           853
# International TV Shows       743
# Children & Family Movies     573
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#          type                   title                        director  \
# 1273    Movie  Blue, Painful, Fragile               Shunsuke Kariyama
# 6488    Movie             City of God  Fernando Meirelles, Katia Lund
# 445     Movie            The Beguiled                   Sofia Coppola
# 3116    Movie           The Two Popes              Fernando Meirelles
# 1308  TV Show                   Booba                   Not Mentioned
#
#                       country  release_year rating   duration  Year  Month  \
# 1273                    Japan          2020  TV-14    119 min  2021      2
# 6488  Brazil, France, Germany          2002      R    130 min  2020      1
# 445             United States          2017      R     94 min  2021      7
# 3116    United Kingdom, Italy          2019  PG-13    126 min  2019     12
# 1308           United Kingdom          2021  TV-Y7  4 Seasons  2021      2
#
#       Day                 Genre           Lead_actor
# ...

# %%
df = df[df["cast"] != "Not Mentioned"] # Removing rows where cast = Not Mentioned
df["cast"].value_counts()
# Out:
# cast
# David Attenborough                                                                                                                                                         19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                    14
# Samuel West                                                                                                                                                                10
# Jeff Dunham                                                                                                                                                                 7
# Michela Luci, Jamie Watson, Eric Peterson, Anna Claire Bartlam, Nicolas Aqui, Cory Doran, Julie Lemieux, Derek McGrath                                                      6
# ...

# %%
df["Lead_actor"] = df["cast"].str.split(",").str[0] # Splitting the column by , and making a new column - Lead_actor
df["Lead_actor"].value_counts().head(5)
# Out:
# Lead_actor
# Shah Rukh Khan        26
# Akshay Kumar          23
# Adam Sandler          20
# Amitabh Bachchan      20
# David Attenborough    20
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#        type                                              title  \
# 8210  Movie  The Bill Murray Stories: Life Lessons Learned ...
# 142   Movie                                    Freedom Writers
# 8652  Movie                                               Ugly
# 8603  Movie                                Tomorrow Never Dies
# 7686  Movie                                           Outlawed
#
#                         director                        country  release_year  \
# 8210              Tommy Avallone                  United States          2018
# 142          Richard LaGravenese         Germany, United States          2007
# 8652              Anurag Kashyap                          India          2013
# 8603          Roger Spottiswoode  United Kingdom, United States          1997
# 7686  Adam Collins, Luke Radford                 United Kingdom          2018
#
#      rating duration  Year  Month  Day               Genre      Lead_actor
# ...

# %%
df.drop(["cast","date_added","listed_in"], axis=1, inplace=True) # Dropping the extra columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df.drop(["cast","date_added","listed_in"], axis=1, inplace=True) # Dropping the extra columns
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
# ...

# %%
df.sample(5)
# Out:
#          type                    title         director  \
# 3771    Movie      The Black Godfather  Reginald Hudlin
# 5084    Movie           The Polka King      Maya Forbes
# 5954    Movie            Even the Rain    Icíar Bollaín
# 3696  TV Show  Record of Grancrest War    Not Mentioned
# 8682    Movie          Vizontele Tuuba   Yılmaz Erdoğan
#
#                     country  release_year rating  duration  Year  Month  Day  \
# 3771          United States          2019  TV-MA   118 min  2019      6    7
# 5084          United States          2018  TV-14    94 min  2018      1   12
# 5954  Spain, Mexico, France          2010  TV-MA   103 min  2011      5   17
# 3696                  Japan          2018  TV-MA  1 Season  2019      7    1
# 8682                 Turkey          2004     NR   106 min  2017      3   10
#
#               Genre       Lead_actor
# 3771  Documentaries   Clarence Avant
# 5084       Comedies       Jack Black
# 5954         Dramas       Luis Tosar
# ...

# %%
df.to_csv("Transformed_data.csv")
